# %% [markdown]
# # SimulateTS Data Generation Smoke Test
#
# Run a tiny simulation to inspect the firm-level and macro-level outputs.

# %%
import sys
from pathlib import Path
import torch
import pandas as pd

# Add repo root to path
try:
    ROOT = Path(__file__).resolve().parent
except NameError:
    ROOT = Path.cwd()
sys.path.append(str(ROOT))

from config import Config
from data.simulate_ts import SimulateTS
from models.policy_value import PolicyValueModel

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
Config.DEVICE = device

# Minimal models needed by SimulateTS
models = {
    'policy_value': PolicyValueModel().to(device),
    'sdf_fc1': None,
    'fc2': None,
    'dist_b': None,
}

sim = SimulateTS(
    models=models,
    config=Config,
    n_paths=1,
    group_size=3,
    horizon=2,
    branch_num=3,
    enable_entry=False,
    enable_exit=False,
    device=device,
)

df_firm, df_macro = sim.simulate()

display(df_firm.head(10))
display(df_macro)
print('Firm columns:', df_firm.columns.tolist())
print('Macro columns:', df_macro.columns.tolist())
# Out:
# Simulating paths: 100%|██████████| 1/1 [00:00<00:00, 188.78it/s]
#    path  t  branch                                ID  entry         b  \
# 0     0  0      -1  db85591ccb924172982fc6dd39f4749e    1.0  0.284551
# 1     0  0      -1  b93a0552f9784726b2ecb884a8e169e7    1.0  0.016749
# 2     0  0      -1  b20374e621f54c31b74c02fea6e32e6b    1.0  0.119669
# 3     0  1       0  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 4     0  1       0  b93a0552f9784726b2ecb884a8e169e7    0.0  0.482999
# 5     0  1       0  b20374e621f54c31b74c02fea6e32e6b    0.0  0.119669
# 6     0  1       1  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 7     0  1       1  b93a0552f9784726b2ecb884a8e169e7    0.0  0.016749
# 8     0  1       1  b20374e621f54c31b74c02fea6e32e6b    0.0  0.119669
# 9     0  1       2  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
#
#           z  ETA         i         x  ...     Bar_i     Bar_z         P  \
# ...

# %%
df_firm[df_firm['ID'] == "db85591ccb924172982fc6dd39f4749e"]
# Out:
#     path  t  branch                                ID  entry         b  \
# 0      0  0      -1  db85591ccb924172982fc6dd39f4749e    1.0  0.284551
# 3      0  1       0  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 6      0  1       1  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 9      0  1       2  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 12     0  1      -1  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 15     0  2       0  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 18     0  2       1  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
# 21     0  2       2  db85591ccb924172982fc6dd39f4749e    0.0  0.284551
#
#            z  ETA         i         x  ...     Bar_i     Bar_z         P  \
# 0   0.257469  0.0  0.199134  0.014007  ...  0.366605  0.597034  0.257123
# 3   0.208572  0.0  0.188051  0.037042  ...  0.340073  0.499559  0.337861
# 6   0.340513  0.0  0.138673  0.025168  ...  0.331688  0.503539  0.335792
# ...

# %%
# Inspect SimulateTS-generated data (episode>0 equivalent)
import torch
from data.simulate_ts import SimulateTS
from models import SDFFC1Combined, PolicyValueModel, FC2Model
from config import Config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
Config.DEVICE = device

# build minimal models (same shapes as training)
models = {
    "sdf_fc1": SDFFC1Combined(
        sdf_input_dim=Config.FC1_INPUT_DIM,
        fc1_input_dim=Config.FC1_INPUT_DIM,
        sdf_hidden_dims=Config.SDF_HIDDEN_DIMS,
        fc1_hidden_dims=Config.FC1_HIDDEN_DIMS,
        w_hidden_dims=Config.SDF_HIDDEN_DIMS,
    ).to(device),
    "policy_value": PolicyValueModel().to(device),
    "fc2": FC2Model(
        input_dim=Config.FC2_INPUT_DIM,
        hidden_dims=Config.FC2_HIDDEN_DIMS,
        quantile_num=Config.QUANTILE_NUM,
    ).to(device),
}

sim = SimulateTS(
    models=models,
    config=Config,
    n_paths=2,
    group_size=2,
    branch_num=Config.BRANCH_NUM,
    horizon=10,
    device=device,
)
df_firm_sim, df_macro_sim = sim.simulate()

print("df_firm_sim shape:", df_firm_sim.shape)
display(df_firm_sim.head())

print("\ndf_macro_sim shape:", df_macro_sim.shape)
display(df_macro_sim.head())
# Out:
# Simulating paths: 100%|██████████| 2/2 [00:00<00:00, 27.61it/s]
# df_firm_sim shape: (1563, 27)
#    path  t  branch                                ID  entry         b  \
# 0     0  0      -1  7c68ddd36b264c9693cdcdedaded4b0b    1.0  0.292417
# 1     0  0      -1  656da8976f5d430da166ee2d91a038cf    1.0  0.432934
# 2     0  1       0  7c68ddd36b264c9693cdcdedaded4b0b    0.0  0.474544
# 3     0  1       0  656da8976f5d430da166ee2d91a038cf    0.0  0.475319
# 4     0  1       1  7c68ddd36b264c9693cdcdedaded4b0b    0.0  0.292417
#
#           z  ETA         i         x  ...     Bar_i     Bar_z         P  \
# 0  0.023751  0.0  0.124414 -0.014116  ...  0.739102  0.476805  0.395064
# 1  0.085086  0.0  0.070241 -0.014116  ...  0.726654  0.470788  0.398191
# 2  0.100623  1.0  0.141392 -0.021868  ...  0.647812  0.509092  0.360503
# 3 -0.023771  1.0  0.179205 -0.021868  ...  0.650478  0.512463  0.359038
# 4  0.105675  0.0  0.005491  0.012773  ...  0.531490  0.494522  0.354007
#
# ...

# %%
df_macro_sim
# Out:
#     path   t  branch          K          C       LnK      Hatc  n_firms  \
# 0      0   0      -1   2.530895   2.160854  0.928573 -0.158058        2
# 1      0   1       0   2.568038   2.102018  0.943142 -0.200232        2
# 2      0   1       1   2.568038   2.393064  0.943142 -0.070557        2
# 3      0   1      -1  10.000000   8.010302  2.302585 -0.221844       10
# 4      0   2       0  10.091946   8.470103  2.311738 -0.175183       10
# 5      0   2       1  10.091946   8.266334  2.311738 -0.199534       10
# 6      0   2      -1  13.011680  10.356865  2.565847 -0.228185       13
# 7      0   3       0  13.060997  10.446395  2.569630 -0.223361       13
# 8      0   3       1  13.060997  11.492341  2.569630 -0.127938       13
# 9      0   3      -1  19.000000  14.786404  2.944439 -0.250718       19
# 10     0   4       0  19.078339  14.735860  2.948554 -0.258257       19
# 11     0   4       1  19.078339  15.743130  2.948554 -0.192137       19
# ...

# %%
# Build batches for each module from simulated data (sdf_fc1, policy_value, fc2)
import torch
from config import HyperParams
from training.episode import Episode, HyperParams
from config import Config
from models import SDFFC1Combined, PolicyValueModel, FC2Model
from data.simulate_ts import SimulateTS

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
Config.DEVICE = device

# Reuse models from previous cell if available; otherwise rebuild
try:
    models
except NameError:
    models = {
        "sdf_fc1": SDFFC1Combined(
            sdf_input_dim=Config.FC1_INPUT_DIM,
            fc1_input_dim=Config.FC1_INPUT_DIM,
            sdf_hidden_dims=Config.SDF_HIDDEN_DIMS,
            fc1_hidden_dims=Config.FC1_HIDDEN_DIMS,
            w_hidden_dims=Config.SDF_HIDDEN_DIMS,
        ).to(device),
        "policy_value": PolicyValueModel().to(device),
        "fc2": FC2Model(
            input_dim=Config.FC2_INPUT_DIM,
            hidden_dims=Config.FC2_HIDDEN_DIMS,
            quantile_num=Config.QUANTILE_NUM,
        ).to(device),
    }

# Simulate a tiny dataset
sim = SimulateTS(
    models=models,
    config=Config,
    n_paths=1,
    group_size=2,
    branch_num=Config.BRANCH_NUM,
    horizon=1,
    device=device,
)
df_firm_sim, df_macro_sim = sim.simulate()

hp = HyperParams()
ep = Episode(models=models, optimizers={}, config=Config, hyperparams=hp, device=device, episode_id=1)

sdf_batches = ep._create_firm_batches_from_df(df_firm_sim, batch_size=4, n_branches=Config.BRANCH_NUM)
pv_batches = ep._create_firm_batches_from_df(df_firm_sim, batch_size=4, n_branches=Config.BRANCH_NUM)
fc2_batches = ep._create_fc2_batches(df_firm_sim, batch_size=4, n_branches=Config.BRANCH_NUM)

print("sdf_batches:", len(sdf_batches))
if sdf_batches:
    b0 = sdf_batches[0]
    print({k: v.shape for k, v in b0.items() if hasattr(v, 'shape')})

print("policy_value batches:", len(pv_batches))
if pv_batches:
    b0 = pv_batches[0]
    print({k: v.shape for k, v in b0.items() if hasattr(v, 'shape')})

print("fc2 batches:", len(fc2_batches))
if fc2_batches:
    b0 = fc2_batches[0]
    print("parent_states length:", len(b0['parent_states']))
    print("children_states length:", len(b0['children_states']))
    if b0['parent_states']:
        print("parent_states[0] shape:", b0['parent_states'][0].shape)
        print("child_state[0] shape:", b0['children_states'][0][0].shape)
# Out:
# Simulating paths: 100%|██████████| 1/1 [00:00<00:00, 183.88it/s]
# sdf_batches: 1
# {'parent': torch.Size([2, 8]), 'child0': torch.Size([2, 8]), 'child1': torch.Size([2, 8])}
# policy_value batches: 1
# {'parent': torch.Size([2, 8]), 'child0': torch.Size([2, 8]), 'child1': torch.Size([2, 8])}
# fc2 batches: 1
# parent_states length: 1
# children_states length: 1
# parent_states[0] shape: torch.Size([2, 7])
# child_state[0] shape: torch.Size([2, 7])

# %%
fc2_batches
# Out:
# [{'parent_states': [tensor([[ 4.3015e-01,  1.3580e-01,  1.0000e+00,  8.6331e-04,  4.4046e-02,
#             -2.0000e+00, -3.5227e-01],
#            [ 3.9342e-01,  2.5317e-01,  0.0000e+00,  5.7814e-02,  4.4046e-02,
#             -2.0000e+00, -3.5227e-01]])],
#   'children_states': [[tensor([[0.4301, 0.1815, 0.0000, 0.0470, 0.0538, 0.0279, 0.0018],
#             [0.3934, 0.2971, 0.0000, 0.0296, 0.0538, 0.0279, 0.0018]]),
#     tensor([[0.4301, 0.1056, 0.0000, 0.0970, 0.0306, 0.0276, 0.0011],
#             [0.3934, 0.2913, 0.0000, 0.0906, 0.0306, 0.0276, 0.0011]])]],
#   'K_parent_list': [tensor([[0.8624],
#            [0.6408]])]}]

# %%
df_firm_sim
# Out:
#    path  t  branch                                ID  entry         b  \
# 0     0  0      -1  c07ca3a0384e43089bcf40560e7636a0    1.0  0.430147
# 1     0  0      -1  8c23fc79e1934c2f9d2cd445ee619a9d    1.0  0.393416
# 2     0  1       0  c07ca3a0384e43089bcf40560e7636a0    0.0  0.430147
# 3     0  1       0  8c23fc79e1934c2f9d2cd445ee619a9d    0.0  0.393416
# 4     0  1       1  c07ca3a0384e43089bcf40560e7636a0    0.0  0.430147
# 5     0  1       1  8c23fc79e1934c2f9d2cd445ee619a9d    0.0  0.393416
#
#           z  ETA         i         x  ...     Bar_i     Bar_z         P  \
# 0  0.135796  1.0  0.000863  0.044046  ...  0.438430  0.472617  0.344003
# 1  0.253167  0.0  0.057814  0.044046  ...  0.572518  0.494306  0.330381
# 2  0.181514  0.0  0.046975  0.053833  ...  0.492024  0.496815  0.347433
# 3  0.297075  0.0  0.029556  0.053833  ...  0.483163  0.493213  0.349431
# 4  0.105646  0.0  0.096986  0.030606  ...  0.490903  0.500000  0.344981
# ...

# %%
# Example: build one FC2 input (phi) from a tiny simulated batch
import torch
from config import Config, HyperParams
from models import SDFFC1Combined, PolicyValueModel, FC2Model
from training.episode import Episode
from data.simulate_ts import SimulateTS

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
Config.DEVICE = device

# Build models (untrained weights, just for shape)
models = {
    'sdf_fc1': SDFFC1Combined(
        sdf_input_dim=Config.FC1_INPUT_DIM,
        fc1_input_dim=Config.FC1_INPUT_DIM,
        sdf_hidden_dims=Config.SDF_HIDDEN_DIMS,
        fc1_hidden_dims=Config.FC1_HIDDEN_DIMS,
        w_hidden_dims=Config.SDF_HIDDEN_DIMS,
    ).to(device),
    'policy_value': PolicyValueModel().to(device),
    'fc2': FC2Model(
        input_dim=Config.FC2_INPUT_DIM,
        hidden_dims=Config.FC2_HIDDEN_DIMS,
        quantile_num=Config.QUANTILE_NUM,
    ).to(device),
}

# Simulate a tiny dataset
sim = SimulateTS(
    models=models,
    config=Config,
    n_paths=1,
    group_size=100,
    branch_num=Config.BRANCH_NUM,
    horizon=1,
    device=device,
)
df_firm, _ = sim.simulate()

# Prepare Episode just to use batch builders
hp = HyperParams()
hp.w_sdf = hp.w_p0 = hp.w_pi = hp.w_q = hp.w_fc2 = 1.0
ep = Episode(models=models, optimizers={}, config=Config, hyperparams=hp, device=device, episode_id=1)

fc2_batches = ep._create_fc2_batches(df_firm, batch_size=4, n_branches=Config.BRANCH_NUM)
print('fc2_batches:', len(fc2_batches))
if fc2_batches:
    batch = fc2_batches[0]
    parent_state = batch['parent_states'][0]
    children_state = batch['children_states'][0][0]
    print('parent_state shape:', parent_state.shape)
    print('child_state shape:', children_state.shape)
    # build one phi manually using FC2.compute_quantile_features
    b_parent = parent_state[:, 0:1]
    z_parent = parent_state[:, 1:2]
    x_parent = parent_state[:, 4:5]
    lnkf_parent = parent_state[:, 6:7]
    b_q, z_q = models['fc2'].compute_quantile_features(b_parent.squeeze(-1), z_parent.squeeze(-1))
    phi = torch.cat([b_q, z_q, x_parent[:1].flatten(), lnkf_parent[:1].flatten()]).unsqueeze(0)
    print('phi shape:', phi.shape)
    hatc_pred, lnk_pred = models['fc2'](phi)
    print('FC2 output shapes:', hatc_pred.shape, lnk_pred.shape)
# Out:
# Simulating paths: 100%|██████████| 1/1 [00:00<00:00, 65.97it/s]
# fc2_batches: 1
# parent_state shape: torch.Size([100, 7])
# child_state shape: torch.Size([100, 7])
# phi shape: torch.Size([1, 202])
# FC2 output shapes: torch.Size([1, 1]) torch.Size([1, 1])

# %%
b_q
# Out:
# tensor([0.0025, 0.0033, 0.0042, 0.0078, 0.0097, 0.0212, 0.0221, 0.0304, 0.0396,
#         0.0434, 0.0522, 0.0691, 0.0790, 0.0809, 0.0890, 0.0924, 0.0933, 0.1049,
#         0.1075, 0.1148, 0.1230, 0.1261, 0.1307, 0.1321, 0.1441, 0.1506, 0.1517,
#         0.1539, 0.1558, 0.1618, 0.1667, 0.1702, 0.1749, 0.1807, 0.1842, 0.1854,
#         0.1866, 0.1895, 0.2042, 0.2131, 0.2143, 0.2370, 0.2547, 0.2572, 0.2580,
#         0.2611, 0.2666, 0.2706, 0.2747, 0.2842, 0.2987, 0.3065, 0.3084, 0.3141,
#         0.3189, 0.3219, 0.3264, 0.3300, 0.3328, 0.3360, 0.3459, 0.3574, 0.3600,
#         0.3611, 0.3619, 0.3652, 0.3724, 0.3780, 0.3800, 0.3848, 0.3875, 0.3908,
#         0.3955, 0.4008, 0.4014, 0.4024, 0.4073, 0.4219, 0.4244, 0.4252, 0.4270,
#         0.4302, 0.4309, 0.4318, 0.4344, 0.4405, 0.4446, 0.4461, 0.4476, 0.4485,
#         0.4529, 0.4537, 0.4569, 0.4605, 0.4747, 0.4799, 0.4803, 0.4867, 0.4916,
#         0.4922])
